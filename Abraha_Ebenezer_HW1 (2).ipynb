# %% [markdown]
# # Homework 1: Python Basics

# %% [markdown]
# **Name: Ebenezer Abraha**
# **Student ID: M21109380**

# %% [markdown]
# *Course: DATA 101 - Fall 2026*

# %% [markdown]
# # Data Science Topics I'm Exiced to Learn
#
# 1. Python Programming
# 2. Data Visualization
# 3. Machine Learning

# %% [markdown]
# |  Course    | Credits |Day / Time      |Location       |
# |----|---:|---|---|
# | Data 101    |  3     | Tuesday/Thursday 12:00 pm | Rockville  |
# | Dance 100  | 3   |   Tuesday/Thursday 10:00 am|  Rockville |
# |COMM 100  | 3|  Tuesday/Thursday 4:00 pm  | Online

# %% [markdown]
# # Create Variables

# %%
product_name = "TV"
price = 500.00
quantity = 5

price = int(price)

print(type(price))

print(f"We have {quantity} units of {product_name} available at ${price} each.")
# Out:
# <class 'int'>
# We have 5 units of TV available at $500 each.

# %% [markdown]
# # Arithmetic and Logic

# %%
total_inventory_value = price * quantity

print(total_inventory_value)

is_greater_than_500 = total_inventory_value > 500

print(is_greater_than_500)

price = 500
quantity = 5
# Out:
# 2500
# True
